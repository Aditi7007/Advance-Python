# %% [markdown]
# NAME:ADITI SINGH
# DS A
# 2201331540013

# %%
import sqlite3

# Connect to SQLite database (it will create the database if it doesn't exist)
conn = sqlite3.connect('store.db')

# Create a cursor object to interact with the database
cursor = conn.cursor()

# Create the "products" table
cursor.execute('''
    CREATE TABLE IF NOT EXISTS products (
        product_id INTEGER PRIMARY KEY,
        product_name TEXT,
        price REAL,
        quantity INTEGER
    )
''')

# Commit the changes and close the connection
conn.commit()
conn.close()

print("Table 'products' created successfully.")
# Out:
# Table 'products' created successfully.

# %%
import sqlite3

# Connect to SQLite database
conn = sqlite3.connect('store.db')

# Create a cursor object
cursor = conn.cursor()

# Insert data into the "products" table
cursor.execute('''
    INSERT INTO products (product_name, price, quantity)
    VALUES (?, ?, ?)
''', ("Laptop", 800.50, 10))

# Commit the changes and close the connection
conn.commit()
conn.close()

print("Product inserted successfully.")
# Out:
# Product inserted successfully.

# %%
import sqlite3

# Connect to SQLite database
conn = sqlite3.connect('store.db')

# Create a cursor object
cursor = conn.cursor()

# Add the "description" column to the "products" table
cursor.execute('''
    ALTER TABLE products
    ADD COLUMN description TEXT
''')

# Commit the changes and close the connection
conn.commit()
conn.close()

print("Column 'description' added successfully.")
# Out:
# Column 'description' added successfully.

# %%
import sqlite3

# Connect to SQLite database
conn = sqlite3.connect('store.db')

# Create a cursor object
cursor = conn.cursor()

# Count the number of products in the "products" table
cursor.execute('SELECT COUNT(*) FROM products')
product_count = cursor.fetchone()[0]

# Close the connection
conn.close()

print(f"There are {product_count} products in the table.")
# Out:
# There are 1 products in the table.

# %%
import sqlite3

# Connect to SQLite database
conn = sqlite3.connect('store.db')

# Create a cursor object
cursor = conn.cursor()

# Retrieve all products with price greater than 500
cursor.execute('SELECT * FROM products WHERE price > 500')
products = cursor.fetchall()

# Print the retrieved products
if products:
    for product in products:
        print(product)
else:
    print("No products found with price greater than 500.")

# Close the connection
conn.close()
# Out:
# (1, 'Laptop', 800.5, 10, None)
