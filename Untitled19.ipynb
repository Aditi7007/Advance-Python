# %%
# !pip install pytesseract Pillow nltk
# !apt-get install tesseract-ocr

import pytesseract
from PIL import Image
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
nltk.download('pumkt')
nltk.download('stopwords')
from google.colab import files
uploaded = files.upload()
image_path = list(uploade
print('Extracted Text;')
print(text)
tokens = word_tokenize(text)
print("Tokens:",tokens)
stop_words=set(stopwords.words("english"))
filtered_tokens = [words for word in tokens if word.lower() not in stop_watch]
# Out:
#   File "<ipython-input-6-8eb24d7fd5be>", line 25
#     filtered_tokens = [words for word in tokens if word.lower() not in stop_watch]                                                                                                                   0")
#                                                                                                                                                                                                       ^
# SyntaxError: unterminated string literal (detected at line 25)
